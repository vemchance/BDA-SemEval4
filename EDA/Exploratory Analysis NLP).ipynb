# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Goat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Goat\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Data

# %% [markdown]
# ## Text Data (Annotations)
#
# TODO:
# Change hardcoded locations

# %%
# dir = change
# change below from hard coded location


anno_subtask1_train = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask1\\train.json')
anno_subtask1_train['subset'] = 'train'
anno_subtask1_val = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask1\\validation.json')
anno_subtask1_val['subset'] = 'val'
anno_subtask1_dev = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask1\\dev_unlabeled.json')

subtask1 = pd.concat([anno_subtask1_train, anno_subtask1_val])

anno_subtask2a_train = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2a\\train.json')
anno_subtask2a_train['subset'] = 'train'
anno_subtask2a_val = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2a\\validation.json')
anno_subtask2a_val['subset'] = 'val'
anno_subtask2a_dev = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2a\\dev_unlabeled.json')

anno_subtask2a_combined = pd.concat([anno_subtask2a_train, anno_subtask2a_val])

anno_subtask2b_train = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2b\\train.json')
anno_subtask2b_train['subset'] = 'train'
anno_subtask2b_val = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2b\\val.json')
anno_subtask2b_val['subset'] = 'val'
anno_subtask2b_dev = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2b\\dev_unlabeled.json')

anno_subtask2b_combined = pd.concat([anno_subtask2b_train, anno_subtask2b_val])

# %% [markdown]
# ## Image Data (Subtask2a and Subtask2b)
# TODO:
# Change hardcoded locations

# %%
path = r'X:\PhD\SemEval Task4\Data\subtask2a_images'
images = [os.path.join(dirpath,f) for (dirpath, dirnames, filenames) in os.walk(path) for f in filenames]
images_df = pd.DataFrame(images, columns=['filepath'])
images_df['image'] = images_df['filepath'].str.split('\\').str[-1]

subtask2a = pd.merge(anno_subtask2a_combined, images_df, on='image')

# %%
path = r'X:\PhD\SemEval Task4\Data\subtask2b_images'
images = [os.path.join(dirpath,f) for (dirpath, dirnames, filenames) in os.walk(path) for f in filenames]
images_df = pd.DataFrame(images, columns=['filepath'])
images_df['image'] = images_df['filepath'].str.split('\\').str[-1]

subtask2b = pd.merge(anno_subtask2b_combined, images_df, on='image')

# has a nan text field so replace it with an empty string
subtask2b['text'] = subtask2b['text'].fillna(' ')
subtask2b
# Out:
#          id                                               text  \
# 0     35807  DONALD TRUMP: BARACK\nOBAMA AND JOE BIDEN\nWIL...
# 1     30562  00\n10% FOR\nTHE BIG GUY\nNANCY'S\nCUT\n@ImMem...
# 2     44163  To much political posting online\nthese days, ...
# 3     24224  I DON'T THINK\nYOU UNDERSTOOD\nWHAT I SAID.\nY...
# 4     31611  ⒸSergey Mihailicenko/Anadolu Agency via Getty ...
# ...     ...                                                ...
# 1345  44900  197\nNazi ain't got no humanity\nThey're the f...
# 1346  12635                   HANG ONTHAVE\nA MEME\nFOR THIS\n
# 1347  12740  HE GAVE HIS BLOOD, SWEAT AND TEARS\nFOR THE AM...
# 1348  46086  BUT I WANTED NORTH\nKOREA TO NUKE US\nTO MAKE ...
# 1349  30279                         AGENDA 21\nDIY.DESPAIR.COM
#
#                     image               label subset  \
# 0      prop_meme_6570.png      propagandistic  train
# 1      prop_meme_8346.png      propagandistic  train
# 2     prop_meme_24378.png  non_propagandistic  train
# 3      prop_meme_2594.png      propagandistic  train
# 4      prop_meme_7654.png      propagandistic  train
# ...                   ...                 ...    ...
# 1345  prop_meme_19869.png      propagandistic    val
# 1346    prop_meme_641.png  non_propagandistic    val
# 1347    prop_meme_746.png      propagandistic    val
# 1348  prop_meme_18775.png      propagandistic    val
# 1349   prop_meme_5619.png      propagandistic    val
#
#                                                filepath
# 0     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 1     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 2     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 3     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 4     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# ...                                                 ...
# 1345  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1346  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1347  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1348  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1349  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
#
# [1350 rows x 6 columns]

# %% [markdown]
# # NLP

# %% [markdown]
# ## Label Distribution

# %% [markdown]
# ### Average Count of Multiclass (Subtask1 and Subtask2a)

# %%
# might as well merge the subtask dataframes
subtask1_t = subtask1
subtask1_t['dataset'] = 'subtask1'
subtask2a_t = subtask2a
subtask2a_t['dataset'] = 'subtask2a'

subtask1_2a = pd.concat([subtask1_t, subtask2a_t])
subtask1_2a['labelcount'] = subtask1_2a['labels'].apply(lambda x: len(x))

# %%
sns.histplot(subtask1_2a, x='labelcount').set_title('Combined Subtask1 and Subtask2 Multiclass Label Counts')
# Out:
# Text(0.5, 1.0, 'Combined Subtask1 and Subtask2 Multiclass Label Counts')

# %%
sns.displot(data=subtask1_2a, col='subset', row='dataset', x='labelcount')
# Out:
# c:\users\goat\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Next step would be look at the crossover between the classes in the diagram/hierarchy, but need to finish JRC helper for this and get a better diagram of the different classes than the one provided by the authors

# %% [markdown]
# ### Label Distribution for Subtask2b

# %%
sns.histplot(subtask2b, x='label').set_title('Combined Subtask1 and Subtask2 Multiclass Label Counts')
# Out:
# Text(0.5, 1.0, 'Combined Subtask1 and Subtask2 Multiclass Label Counts')

# %%
sns.displot(data=subtask2b, col='subset', x='label')
# Out:
# c:\users\goat\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Text Analysis

# %% [markdown]
# ### Woooo Word Clouds

# %%
# can't fully get rid of linebreaks, but all good
stop_words = stopwords.words('english') 

def generate_wc(data, title):
    cloud = WordCloud(width=400,
                      height=330,
                      stopwords=stop_words,
                      collocations=True).generate_from_text(' '.join(s for s in data))
    plt.figure(figsize=(10,8))
    plt.imshow(cloud)
    plt.axis('off')
    plt.title(title, fontsize=13)
    plt.show()

# %%
generate_wc(subtask1_2a['text'], 'Subtsk1 and Subtask2a')

# %%
generate_wc(subtask1_2a[subtask1_2a['dataset'] == 'subtask1']['text'], 'Subtask 1')

# %%
generate_wc(subtask1_2a[subtask1_2a['dataset'] == 'subtask2a']['text'], 'Subtask 2a')

# %%
generate_wc(subtask2b['text'], 'Subtask2b')

# %% [markdown]
# ### Fed up of Word Clouds: Frequency Per Class
#
# For this part, we will explode the label lists to duplicate a row per label. Ideally, the goal would be to investigate whether certain named entities tend to appear in each type of technique over others; anything we can gather from the terminology used; specific sentiment .etc.
#
# Given the word clouds show highly similar words per subset, we're just going to use the combined subtask1 and subtask2a frame for this, ignoring subtask2b which is a binary classification task.
#
# TODO:
# - Add stopwords
# - Different tokenizer method/get rid of boring words like 'the'
# - ESCAPE CHARACTERS

# %%
# try to clean those pesky escape characters

subtask1_2a['text'] = subtask1_2a['text'].str.encode('ascii', 'ignore').str.decode('ascii')
subtask1_2a['text'] = subtask1_2a['text'].str.replace('\r\n',' ').replace('\n',' ')
subtask1_2a['text'] = subtask1_2a['text'].str.replace('\\n',' ').replace('\\\\n',' ')
subtask1_2a['text']
# Out:
# 0       THIS IS WHY YOU NEED  A SHARPIE WITH YOU AT AL...
# 1       GOOD NEWS!  NAZANIN ZAGHARI-RATCLIFFE AND ANOO...
# 2                                 PAING PHYO MIN IS FREE!
# 3       Move your ships away!  oooook  Move your ships...
# 4                WHEN YOU'RE THE FBI, THEY LET YOU DO IT.
#                               ...
# 7995    While Revolutionaries as Individuals can be mu...
# 7996    A War in the Middle East  Every US President I...
# 7997    A War in the Middle East  Every US President I...
# 7998    POLISH VS RUSSIAN HISTORY  1573  DEMOCRATIC EL...
# 7999    POLISH VS RUSSIAN HISTORY  1573  DEMOCRATIC EL...
# Name: text, Length: 15500, dtype: object

# %%
#subtask1_2a['labels']=subtask1_2a['labels'].astype(str)

# %%
big_subtasks = subtask1_2a.explode('labels')
big_subtasks.dropna(subset='labels', inplace=True)
big_subtasks
# Out:
#          id                                               text  \
# 0     65635  THIS IS WHY YOU NEED  A SHARPIE WITH YOU AT AL...
# 1     67927  GOOD NEWS!  NAZANIN ZAGHARI-RATCLIFFE AND ANOO...
# 1     67927  GOOD NEWS!  NAZANIN ZAGHARI-RATCLIFFE AND ANOO...
# 4     67641           WHEN YOU'RE THE FBI, THEY LET YOU DO IT.
# 6     79204  JANUARY 2021  YOU DON'T BUY A 12 MILLION DOLLA...
# ...     ...                                                ...
# 7998  67141  POLISH VS RUSSIAN HISTORY  1573  DEMOCRATIC EL...
# 7998  67141  POLISH VS RUSSIAN HISTORY  1573  DEMOCRATIC EL...
# 7999  67141  POLISH VS RUSSIAN HISTORY  1573  DEMOCRATIC EL...
# 7999  67141  POLISH VS RUSSIAN HISTORY  1573  DEMOCRATIC EL...
# 7999  67141  POLISH VS RUSSIAN HISTORY  1573  DEMOCRATIC EL...
#
#                                     labels  \
# 0     Black-and-white Fallacy/Dictatorship
# 1                          Loaded Language
# 1         Glittering generalities (Virtue)
# 4               Thought-terminating cliché
# 6                             Whataboutism
# ...                                    ...
# 7998                              Transfer
# 7998                           Flag-waving
# 7999                                Smears
# 7999                              Transfer
# 7999                           Flag-waving
#
#                                                    link subset    dataset  \
# 0     https://www.facebook.com/photo/?fbid=402355213...  train   subtask1
# 1     https://www.facebook.com/amnesty/photos/531198...  train   subtask1
# 1     https://www.facebook.com/amnesty/photos/531198...  train   subtask1
# 4     https://www.facebook.com/AddictingInfoOrg/phot...  train   subtask1
# 6     https://www.facebook.com/ResistanceFeed/photos...  train   subtask1
# ...                                                 ...    ...        ...
# 7998  https://www.facebook.com/photo/?fbid=101757093...    val  subtask2a
# 7998  https://www.facebook.com/photo/?fbid=101757093...    val  subtask2a
# 7999  https://www.facebook.com/photo/?fbid=101757093...    val  subtask2a
# 7999  https://www.facebook.com/photo/?fbid=101757093...    val  subtask2a
# 7999  https://www.facebook.com/photo/?fbid=101757093...    val  subtask2a
#
#                     image                                           filepath  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 1                     NaN                                                NaN
# 4                     NaN                                                NaN
# 6                     NaN                                                NaN
# ...                   ...                                                ...
# 7998  prop_meme_11891.png  X:\PhD\SemEval Task4\Data\subtask2a_images\dev...
# 7998  prop_meme_11891.png  X:\PhD\SemEval Task4\Data\subtask2a_images\dev...
# 7999  prop_meme_11891.png  X:\PhD\SemEval Task4\Data\subtask2a_images\val...
# 7999  prop_meme_11891.png  X:\PhD\SemEval Task4\Data\subtask2a_images\val...
# 7999  prop_meme_11891.png  X:\PhD\SemEval Task4\Data\subtask2a_images\val...
#
#       labelcount
# 0              1
# 1              2
# 1              2
# 4              1
# 6              1
# ...          ...
# 7998           3
# 7998           3
# 7999           3
# 7999           3
# 7999           3
#
# [30166 rows x 9 columns]

# %%
def word_frequency(text):
    text = ' '.join(text)
    text = word_tokenize(text) #tokenized returns a few escape characters
    text = ' '.join(text)
    
    wordcloud = WordCloud(stopwords = stop_words,
                      collocations=True).generate(text)
    
    text_dictionary = wordcloud.process_text(text)
    word_freq = {k: v for k, v in sorted(text_dictionary.items(),reverse=True, key=lambda item: item[1])}
    rel_freq=wordcloud.words_
    
    print(list(word_freq.items())[:20])
    print(list(x for x in rel_freq.items())[:20])

# %%
labels = big_subtasks['labels'].unique()

for i in labels:
    print(f'{i} Frequency')
    print('\n---')
    word_frequency(big_subtasks[big_subtasks['labels'] == i]['text'])
    print('\n--------------')
# Out:
# Black-and-white Fallacy/Dictatorship Frequency
#
# ---
# [("n't", 246), ('people', 153), ('one', 117), ('LIKE', 104), ('Trump', 103), ('Vote', 99), ('AMERICA', 99), ('U', 98), ('right', 95), ('want', 93), ('STOP', 89), ('Ukraine', 88), ('must', 85), ('would', 83), ('NEVER', 82), ('country', 82), ('GET', 81), ('LET', 79), ('GOVERNMENT', 78), ('TIME', 75)]
# [("n't", 1.0), ('people', 0.6219512195121951), ('one', 0.47560975609756095), ('LIKE', 0.42276422764227645), ('Trump', 0.4186991869918699), ('Vote', 0.4024390243902439), ('AMERICA', 0.4024390243902439), ('U', 0.3983739837398374), ('right', 0.3861788617886179), ('want', 0.3780487804878049), ('STOP', 0.3617886178861789), ('Ukraine', 0.35772357723577236), ('must', 0.34552845528455284), ('would', 0.33739837398373984), ('NEVER', 0.3333333333333333), ('country', 0.3333333333333333), ('GET', 0.32926829268292684), ('LET', 0.32113821138211385), ('GOVERNMENT', 0.3170731707317073), ('TIME', 0.3048780487804878)]
#
# --------------
# Loaded Language Frequency
#
# ---
# [('people', 406), ("n't", 300), ('Trump', 295), ('U', 293), ('one', 238), ('GOVERNMENT', 227), ('like', 221), ('AMERICA', 212), ('Ukraine', 184), ('country', 180), ('world', 172), ('Russian', 171), ('PRESIDENT', 170), ('would', 163), ('WAR', 158), ('Russia', 158), ('American', 157), ('right', 143), ('say', 139), ('get', 137)]
# [('people', 1.0), ("n't", 0.7389162561576355), ('Trump', 0.7266009852216748), ('U', 0.7216748768472906), ('one', 0.5862068965517241), ('GOVERNMENT', 0.5591133004926109), ('like', 0.5443349753694581), ('AMERICA', 0.5221674876847291), ('Ukraine', 0.45320197044334976), ('country', 0.4433497536945813), ('world', 0.4236453201970443), ('Russian', 0.4211822660098522), ('PRESIDENT', 0.4187192118226601), ('would', 0.4014778325123153), ('WAR', 0.3891625615763547), ('Russia', 0.3891625615763547), ('American', 0.3866995073891626), ('right', 0.3522167487684729), ('say', 0.34236453201970446), ('get', 0.3374384236453202)]
#
# --------------
# Glittering generalities (Virtue) Frequency
#
# ---
# [('Trump', 240), ('President', 180), ('President Trump', 113), ('man', 102), ('Donald Trump', 98), ('THANK', 93), ('country', 90), ('people', 89), ("n't", 87), ('U', 87), ('America', 80), ('one', 79), ('LIKE', 78), ('time', 67), ('never', 65), ('back', 62), ('American', 61), ('want', 57), ('would', 56), ('love', 56)]
# [('Trump', 1.0), ('President', 0.75), ('President Trump', 0.4708333333333333), ('man', 0.425), ('Donald Trump', 0.4083333333333333), ('THANK', 0.3875), ('country', 0.375), ('people', 0.37083333333333335), ("n't", 0.3625), ('U', 0.3625), ('America', 0.3333333333333333), ('one', 0.32916666666666666), ('LIKE', 0.325), ('time', 0.2791666666666667), ('never', 0.2708333333333333), ('back', 0.25833333333333336), ('American', 0.25416666666666665), ('want', 0.2375), ('would', 0.23333333333333334), ('love', 0.23333333333333334)]
#
# --------------
# Thought-terminating cliché Frequency
#
# ---
# [("n't", 192), ('people', 156), ('government', 119), ('U', 100), ('RIGHT', 84), ('NEVER', 80), ('one', 75), ('Trump', 74), ('WAR', 74), ('time', 67), ('would', 67), ('need', 63), ('country', 62), ('PRESIDENT', 60), ('world', 57), ('like', 57), ('know', 54), ('America', 52), ('want', 49), ('Ukraine', 48)]
# [("n't", 1.0), ('people', 0.8125), ('government', 0.6197916666666666), ('U', 0.5208333333333334), ('RIGHT', 0.4375), ('NEVER', 0.4166666666666667), ('one', 0.390625), ('Trump', 0.3854166666666667), ('WAR', 0.3854166666666667), ('time', 0.3489583333333333), ('would', 0.3489583333333333), ('need', 0.328125), ('country', 0.3229166666666667), ('PRESIDENT', 0.3125), ('world', 0.296875), ('like', 0.296875), ('know', 0.28125), ('America', 0.2708333333333333), ('want', 0.2552083333333333), ('Ukraine', 0.25)]
#
# --------------
# Whataboutism Frequency
#
# ---
# [('people', 127), ("N'T", 108), ('Trump', 102), ('U', 64), ('YEAR', 52), ('like', 51), ('ONE', 44), ('GUN', 43), ('get', 38), ('PRESIDENT', 38), ('Democrat', 38), ('would', 37), ('American', 37), ('government', 36), ('DEATH', 36), ('Ukraine', 32), ('MEDIA', 32), ('give', 32), ('man', 30), ('want', 30)]
# [('people', 1.0), ("N'T", 0.8503937007874016), ('Trump', 0.8031496062992126), ('U', 0.5039370078740157), ('YEAR', 0.4094488188976378), ('like', 0.4015748031496063), ('ONE', 0.3464566929133858), ('GUN', 0.33858267716535434), ('get', 0.2992125984251969), ('PRESIDENT', 0.2992125984251969), ('Democrat', 0.2992125984251969), ('would', 0.29133858267716534), ('American', 0.29133858267716534), ('government', 0.28346456692913385), ('DEATH', 0.28346456692913385), ('Ukraine', 0.25196850393700787), ('MEDIA', 0.25196850393700787), ('give', 0.25196850393700787), ('man', 0.23622047244094488), ('want', 0.23622047244094488)]
#
# --------------
# Slogans Frequency
#
# ---
# [('TRUMP', 228), ('people', 128), ("n't", 127), ('NEVER', 95), ('RIGHT', 93), ('STAND', 91), ('AMERICA GREAT', 85), ('U', 83), ('PRESIDENT', 81), ('LET', 79), ('FREEDOM', 77), ('MAKE AMERICA', 74), ('one', 69), ('WORLD', 64), ('LIKE', 57), ('time', 57), ('free', 52), ('want', 50), ('country', 49), ('LOVE', 48)]
# [('TRUMP', 1.0), ('people', 0.5614035087719298), ("n't", 0.5570175438596491), ('NEVER', 0.4166666666666667), ('RIGHT', 0.40789473684210525), ('STAND', 0.3991228070175439), ('AMERICA GREAT', 0.37280701754385964), ('U', 0.36403508771929827), ('PRESIDENT', 0.35526315789473684), ('LET', 0.34649122807017546), ('FREEDOM', 0.33771929824561403), ('MAKE AMERICA', 0.32456140350877194), ('one', 0.3026315789473684), ('WORLD', 0.2807017543859649), ('LIKE', 0.25), ('time', 0.25), ('free', 0.22807017543859648), ('want', 0.21929824561403508), ('country', 0.2149122807017544), ('LOVE', 0.21052631578947367)]
#
# --------------
# Causal Oversimplification Frequency
#
# ---
# [("n't", 104), ('people', 69), ('Trump', 56), ('Ukraine', 46), ('world', 43), ('one', 36), ('GOVERNMENT', 35), ('country', 34), ('WAR', 34), ('Russia', 33), ('would', 32), ('MEDIA', 32), ('U', 31), ('America', 30), ('YEAR', 28), ('Hate', 28), ('Democrat', 28), ('AMERICAN', 27), ('LIKE', 26), ('way', 25)]
# [("n't", 1.0), ('people', 0.6634615384615384), ('Trump', 0.5384615384615384), ('Ukraine', 0.4423076923076923), ('world', 0.41346153846153844), ('one', 0.34615384615384615), ('GOVERNMENT', 0.33653846153846156), ('country', 0.3269230769230769), ('WAR', 0.3269230769230769), ('Russia', 0.3173076923076923), ('would', 0.3076923076923077), ('MEDIA', 0.3076923076923077), ('U', 0.2980769230769231), ('America', 0.28846153846153844), ('YEAR', 0.2692307692307692), ('Hate', 0.2692307692307692), ('Democrat', 0.2692307692307692), ('AMERICAN', 0.25961538461538464), ('LIKE', 0.25), ('way', 0.2403846153846154)]
#
# --------------
# Smears Frequency
#
# ---
# [('Trump', 645), ("n't", 460), ('people', 377), ('like', 359), ('U', 359), ('one', 298), ('DEMOCRAT', 289), ('Russia', 272), ('Biden', 271), ('PRESIDENT', 254), ('Russian', 242), ('year', 239), ('get', 238), ('Ukraine', 226), ('say', 225), ('DONALD TRUMP', 225), ('America', 219), ('WANT', 216), ('Putin', 210), ('GOVERNMENT', 207)]
# [('Trump', 1.0), ("n't", 0.7131782945736435), ('people', 0.5844961240310077), ('like', 0.5565891472868217), ('U', 0.5565891472868217), ('one', 0.462015503875969), ('DEMOCRAT', 0.448062015503876), ('Russia', 0.42170542635658914), ('Biden', 0.4201550387596899), ('PRESIDENT', 0.3937984496124031), ('Russian', 0.3751937984496124), ('year', 0.3705426356589147), ('get', 0.3689922480620155), ('Ukraine', 0.35038759689922483), ('say', 0.3488372093023256), ('DONALD TRUMP', 0.3488372093023256), ('America', 0.3395348837209302), ('WANT', 0.33488372093023255), ('Putin', 0.32558139534883723), ('GOVERNMENT', 0.3209302325581395)]
#
# --------------
# Name calling/Labeling Frequency
#
# ---
# [('TRUMP', 341), ('people', 336), ("n't", 218), ('LIKE', 206), ('U', 204), ('PRESIDENT', 195), ('one', 193), ('AMERICA', 156), ('world', 155), ('man', 154), ('government', 148), ('AMERICAN', 133), ('country', 127), ('right', 126), ('want', 125), ('know', 122), ('think', 118), ('time', 115), ('Vote', 111), ('BACK', 109)]
# [('TRUMP', 1.0), ('people', 0.9853372434017595), ("n't", 0.6392961876832844), ('LIKE', 0.6041055718475073), ('U', 0.5982404692082112), ('PRESIDENT', 0.5718475073313783), ('one', 0.5659824046920822), ('AMERICA', 0.4574780058651026), ('world', 0.45454545454545453), ('man', 0.45161290322580644), ('government', 0.4340175953079179), ('AMERICAN', 0.39002932551319647), ('country', 0.3724340175953079), ('right', 0.36950146627565983), ('want', 0.36656891495601174), ('know', 0.35777126099706746), ('think', 0.3460410557184751), ('time', 0.33724340175953077), ('Vote', 0.3255131964809384), ('BACK', 0.3196480938416422)]
#
# --------------
# Appeal to authority Frequency
#
# ---
# [('people', 318), ("n't", 208), ('Trump', 196), ('Donald Trump', 170), ('one', 169), ('country', 160), ('like', 156), ('U', 156), ('President', 139), ('American', 132), ('think', 131), ('government', 131), ('America', 128), ('never', 121), ('right', 121), ('would', 119), ('President Trump', 117), ('freedom', 110), ('President Donald', 110), ('world', 108)]
# [('people', 1.0), ("n't", 0.6540880503144654), ('Trump', 0.6163522012578616), ('Donald Trump', 0.5345911949685535), ('one', 0.5314465408805031), ('country', 0.5031446540880503), ('like', 0.49056603773584906), ('U', 0.49056603773584906), ('President', 0.4371069182389937), ('American', 0.41509433962264153), ('think', 0.4119496855345912), ('government', 0.4119496855345912), ('America', 0.4025157232704403), ('never', 0.3805031446540881), ('right', 0.3805031446540881), ('would', 0.3742138364779874), ('President Trump', 0.36792452830188677), ('freedom', 0.34591194968553457), ('President Donald', 0.34591194968553457), ('world', 0.33962264150943394)]
#
# --------------
# Exaggeration/Minimisation Frequency
#
# ---
# [('NEVER', 75), ('HISTORY', 72), ('EVER', 71), ('world', 69), ('people', 66), ('Trump', 65), ('America', 64), ('U', 63), ("n't", 62), ('one', 59), ('MAN', 59), ('country', 58), ('President', 54), ('EVERYTHING', 51), ('Donald Trump', 48), ('time', 47), ('get', 41), ('RIGHT', 38), ('like', 38), ('year', 37)]
# [('NEVER', 1.0), ('HISTORY', 0.96), ('EVER', 0.9466666666666667), ('world', 0.92), ('people', 0.88), ('Trump', 0.8666666666666667), ('America', 0.8533333333333334), ('U', 0.84), ("n't", 0.8266666666666667), ('one', 0.7866666666666666), ('MAN', 0.7866666666666666), ('country', 0.7733333333333333), ('President', 0.72), ('EVERYTHING', 0.68), ('Donald Trump', 0.64), ('time', 0.6266666666666667), ('get', 0.5466666666666666), ('RIGHT', 0.5066666666666667), ('like', 0.5066666666666667), ('year', 0.49333333333333335)]
#
# --------------
# Repetition Frequency
#
# ---
# [("n't", 137), ('people', 81), ('never', 71), ('U', 68), ('Vote', 59), ('one', 58), ('get', 44), ('love', 43), ('America', 41), ('want', 41), ('WAR', 40), ('TAX', 40), ('like', 39), ('right', 39), ('American', 39), ('think', 35), ('world', 35), ('government', 35), ('year', 35), ('man', 34)]
# [("n't", 1.0), ('people', 0.5912408759124088), ('never', 0.5182481751824818), ('U', 0.49635036496350365), ('Vote', 0.4306569343065693), ('one', 0.4233576642335766), ('get', 0.32116788321167883), ('love', 0.31386861313868614), ('America', 0.29927007299270075), ('want', 0.29927007299270075), ('WAR', 0.291970802919708), ('TAX', 0.291970802919708), ('like', 0.2846715328467153), ('right', 0.2846715328467153), ('American', 0.2846715328467153), ('think', 0.25547445255474455), ('world', 0.25547445255474455), ('government', 0.25547445255474455), ('year', 0.25547445255474455), ('man', 0.24817518248175183)]
#
# --------------
# Flag-waving Frequency
#
# ---
# [('AMERICA', 218), ('TRUMP', 210), ('AMERICAN', 178), ('country', 161), ('PRESIDENT', 137), ('people', 132), ('U', 123), ("n't", 102), ('Donald Trump', 98), ('never', 96), ('back', 92), ('freedom', 89), ('love', 86), ('one', 80), ('stand', 79), ('MAN', 78), ('PRESIDENT TRUMP', 76), ('nation', 72), ('want', 68), ('LIKE', 66)]
# [('AMERICA', 1.0), ('TRUMP', 0.963302752293578), ('AMERICAN', 0.8165137614678899), ('country', 0.7385321100917431), ('PRESIDENT', 0.6284403669724771), ('people', 0.6055045871559633), ('U', 0.5642201834862385), ("n't", 0.46788990825688076), ('Donald Trump', 0.44954128440366975), ('never', 0.44036697247706424), ('back', 0.42201834862385323), ('freedom', 0.40825688073394495), ('love', 0.3944954128440367), ('one', 0.3669724770642202), ('stand', 0.3623853211009174), ('MAN', 0.3577981651376147), ('PRESIDENT TRUMP', 0.3486238532110092), ('nation', 0.3302752293577982), ('want', 0.3119266055045872), ('LIKE', 0.30275229357798167)]
#
# --------------
# Appeal to fear/prejudice Frequency
#
# ---
# [('people', 97), ("n't", 93), ('U', 88), ('AMERICA', 84), ('WORLD', 78), ('gun', 62), ('AMERICAN', 57), ('TRUMP', 53), ('Ukraine', 52), ('want', 48), ('would', 47), ('WAR', 47), ('government', 45), ('freedom', 44), ('country', 41), ('NEW', 41), ('like', 40), ('LET', 39), ('time', 39), ('President', 38)]
# [('people', 1.0), ("n't", 0.9587628865979382), ('U', 0.9072164948453608), ('AMERICA', 0.865979381443299), ('WORLD', 0.8041237113402062), ('gun', 0.6391752577319587), ('AMERICAN', 0.5876288659793815), ('TRUMP', 0.5463917525773195), ('Ukraine', 0.5360824742268041), ('want', 0.4948453608247423), ('would', 0.4845360824742268), ('WAR', 0.4845360824742268), ('government', 0.4639175257731959), ('freedom', 0.4536082474226804), ('country', 0.422680412371134), ('NEW', 0.422680412371134), ('like', 0.41237113402061853), ('LET', 0.4020618556701031), ('time', 0.4020618556701031), ('President', 0.3917525773195876)]
#
# --------------
# Reductio ad hitlerum Frequency
#
# ---
# [('people', 24), ('Nazi', 20), ('Hitler', 19), ('like', 19), ("n't", 18), ('American', 18), ('would', 16), ('GOVERNMENT', 15), ('Germany', 14), ('PUTIN', 14), ('OBAMA', 14), ('UKRAINE', 13), ('president', 13), ('gun', 12), ('want', 12), ('U', 12), ('Democrat', 12), ('Republican', 12), ('time', 11), ('TRUMP', 11)]
# [('people', 1.0), ('Nazi', 0.8333333333333334), ('Hitler', 0.7916666666666666), ('like', 0.7916666666666666), ("n't", 0.75), ('American', 0.75), ('would', 0.6666666666666666), ('GOVERNMENT', 0.625), ('Germany', 0.5833333333333334), ('PUTIN', 0.5833333333333334), ('OBAMA', 0.5833333333333334), ('UKRAINE', 0.5416666666666666), ('president', 0.5416666666666666), ('gun', 0.5), ('want', 0.5), ('U', 0.5), ('Democrat', 0.5), ('Republican', 0.5), ('time', 0.4583333333333333), ('TRUMP', 0.4583333333333333)]
#
# --------------
# Doubt Frequency
#
# ---
# [("n't", 142), ('THINK', 76), ('WOULD', 71), ('people', 69), ('TRUMP', 61), ('PRESIDENT', 60), ('YEAR', 59), ('U', 55), ('government', 54), ('get', 54), ('KNOW', 52), ('say', 47), ('world', 42), ('one', 42), ('want', 41), ('DEATH', 41), ('LIKE', 40), ('vaccine', 38), ('NEW', 37), ('TAX', 36)]
# [("n't", 1.0), ('THINK', 0.5352112676056338), ('WOULD', 0.5), ('people', 0.4859154929577465), ('TRUMP', 0.4295774647887324), ('PRESIDENT', 0.4225352112676056), ('YEAR', 0.4154929577464789), ('U', 0.3873239436619718), ('government', 0.38028169014084506), ('get', 0.38028169014084506), ('KNOW', 0.36619718309859156), ('say', 0.33098591549295775), ('world', 0.29577464788732394), ('one', 0.29577464788732394), ('want', 0.2887323943661972), ('DEATH', 0.2887323943661972), ('LIKE', 0.28169014084507044), ('vaccine', 0.2676056338028169), ('NEW', 0.2605633802816901), ('TAX', 0.2535211267605634)]
#
# --------------
# Misrepresentation of Someone's Position (Straw Man) Frequency
#
# ---
# [("N'T", 33), ('PARTIES', 21), ('people', 20), ('U', 15), ('WANT', 15), ('Russia', 14), ('say', 14), ('Trump', 13), ('SAID', 13), ('LIKE', 13), ('LET', 12), ('GOVERNMENT', 11), ('right', 11), ('year', 10), ('going', 10), ('even', 10), ('HILLARY', 10), ('could', 9), ('black', 9), ('VOTE', 9)]
# [("N'T", 1.0), ('PARTIES', 0.6363636363636364), ('people', 0.6060606060606061), ('U', 0.45454545454545453), ('WANT', 0.45454545454545453), ('Russia', 0.42424242424242425), ('say', 0.42424242424242425), ('Trump', 0.3939393939393939), ('SAID', 0.3939393939393939), ('LIKE', 0.3939393939393939), ('LET', 0.36363636363636365), ('GOVERNMENT', 0.3333333333333333), ('right', 0.3333333333333333), ('year', 0.30303030303030304), ('going', 0.30303030303030304), ('even', 0.30303030303030304), ('HILLARY', 0.30303030303030304), ('could', 0.2727272727272727), ('black', 0.2727272727272727), ('VOTE', 0.2727272727272727)]
#
# --------------
# Obfuscation, Intentional vagueness, Confusion Frequency
#
# ---
# [('year', 15), ('U', 13), ('CHRISTMAS', 11), ("n't", 11), ('today', 10), ('know', 9), ('live', 8), ('PEOPLE', 8), ('looking', 8), ('JOE BIDEN', 8), ('taken', 7), ('would', 7), ('ONE', 7), ('Trump', 6), ('TRUTH', 6), ('something', 6), ('question', 6), ('HELP', 6), ('CHRISTMAS TREE', 6), ('TOLD', 5)]
# [('year', 1.0), ('U', 0.8666666666666667), ('CHRISTMAS', 0.7333333333333333), ("n't", 0.7333333333333333), ('today', 0.6666666666666666), ('know', 0.6), ('live', 0.5333333333333333), ('PEOPLE', 0.5333333333333333), ('looking', 0.5333333333333333), ('JOE BIDEN', 0.5333333333333333), ('taken', 0.4666666666666667), ('would', 0.4666666666666667), ('ONE', 0.4666666666666667), ('Trump', 0.4), ('TRUTH', 0.4), ('something', 0.4), ('question', 0.4), ('HELP', 0.4), ('CHRISTMAS TREE', 0.4), ('TOLD', 0.3333333333333333)]
#
# --------------
# Bandwagon Frequency
#
# ---
# [('TRUMP', 65), ('PRESIDENT', 34), ('LIKE', 32), ('AGREE', 23), ('AMERICAN', 23), ('SHARE', 21), ('BIDEN', 20), ('VOTE', 20), ('U', 20), ('million', 19), ('PRESIDENT TRUMP', 19), ('ELSE', 18), ('WANT', 18), ('SUPPORT', 16), ('one', 15), ('STILL', 14), ('stand', 14), ('ELSE AGREES', 14), ('join', 13), ('WOULD', 13)]
# [('TRUMP', 1.0), ('PRESIDENT', 0.5230769230769231), ('LIKE', 0.49230769230769234), ('AGREE', 0.35384615384615387), ('AMERICAN', 0.35384615384615387), ('SHARE', 0.3230769230769231), ('BIDEN', 0.3076923076923077), ('VOTE', 0.3076923076923077), ('U', 0.3076923076923077), ('million', 0.2923076923076923), ('PRESIDENT TRUMP', 0.2923076923076923), ('ELSE', 0.27692307692307694), ('WANT', 0.27692307692307694), ('SUPPORT', 0.24615384615384617), ('one', 0.23076923076923078), ('STILL', 0.2153846153846154), ('stand', 0.2153846153846154), ('ELSE AGREES', 0.2153846153846154), ('join', 0.2), ('WOULD', 0.2)]
#
# --------------
# Presenting Irrelevant Data (Red Herring) Frequency
#
# ---
# [("n't", 28), ('TRUMP', 19), ('would', 17), ('Russia', 15), ('NEW', 14), ('year', 13), ('JESUS', 13), ('said', 12), ('like', 12), ('Ukraine', 11), ('US', 10), ('expert', 10), ('day', 10), ('WORLD', 10), ('God', 9), ('say', 8), ('know', 8), ('article', 8), ('tongue', 8), ('WANT', 7)]
# [("n't", 1.0), ('TRUMP', 0.6785714285714286), ('would', 0.6071428571428571), ('Russia', 0.5357142857142857), ('NEW', 0.5), ('year', 0.4642857142857143), ('JESUS', 0.4642857142857143), ('said', 0.42857142857142855), ('like', 0.42857142857142855), ('Ukraine', 0.39285714285714285), ('US', 0.35714285714285715), ('expert', 0.35714285714285715), ('day', 0.35714285714285715), ('WORLD', 0.35714285714285715), ('God', 0.32142857142857145), ('say', 0.2857142857142857), ('know', 0.2857142857142857), ('article', 0.2857142857142857), ('tongue', 0.2857142857142857), ('WANT', 0.25)]
#
# --------------
# Transfer Frequency
#
# ---
# [("n't", 110), ('Ukraine', 102), ('people', 95), ('Russia', 95), ('Russian', 93), ('TRUMP', 84), ('U', 84), ('Putin', 76), ('like', 74), ('GOVERNMENT', 67), ('PRESIDENT', 66), ('NEW', 64), ('ONE', 61), ('WORLD', 50), ('right', 50), ('WAR', 49), ('get', 48), ('BIDEN', 48), ('want', 43), ('need', 42)]
# [("n't", 1.0), ('Ukraine', 0.9272727272727272), ('people', 0.8636363636363636), ('Russia', 0.8636363636363636), ('Russian', 0.8454545454545455), ('TRUMP', 0.7636363636363637), ('U', 0.7636363636363637), ('Putin', 0.6909090909090909), ('like', 0.6727272727272727), ('GOVERNMENT', 0.6090909090909091), ('PRESIDENT', 0.6), ('NEW', 0.5818181818181818), ('ONE', 0.5545454545454546), ('WORLD', 0.45454545454545453), ('right', 0.45454545454545453), ('WAR', 0.44545454545454544), ('get', 0.43636363636363634), ('BIDEN', 0.43636363636363634), ('want', 0.39090909090909093), ('need', 0.38181818181818183)]
#
# --------------
# Appeal to (Strong) Emotions Frequency
#
# ---
# [('U', 45), ('PEOPLE', 43), ("n't", 38), ('Ukraine', 36), ('GOVERNMENT', 29), ('WORLD', 26), ('TRUMP', 26), ('AMERICA', 26), ('children', 24), ('WAR', 24), ('like', 24), ('love', 23), ('Russian', 23), ('ONE', 21), ('SYRIA', 20), ('YEAR', 20), ('GET', 20), ('AMERICAN', 19), ('DAY', 18), ('Vote', 18)]
# [('U', 1.0), ('PEOPLE', 0.9555555555555556), ("n't", 0.8444444444444444), ('Ukraine', 0.8), ('GOVERNMENT', 0.6444444444444445), ('WORLD', 0.5777777777777777), ('TRUMP', 0.5777777777777777), ('AMERICA', 0.5777777777777777), ('children', 0.5333333333333333), ('WAR', 0.5333333333333333), ('like', 0.5333333333333333), ('love', 0.5111111111111111), ('Russian', 0.5111111111111111), ('ONE', 0.4666666666666667), ('SYRIA', 0.4444444444444444), ('YEAR', 0.4444444444444444), ('GET', 0.4444444444444444), ('AMERICAN', 0.4222222222222222), ('DAY', 0.4), ('Vote', 0.4)]
#
# --------------

# %% [markdown]
# ### TF-IDF Cosine Similarity

# %%
# run vectorizer on the joblot for now

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(raw_documents=big_subtasks['text']).toarray()

pca = PCA(n_components=2)

df2d = pd.DataFrame(pca.fit_transform(tfidf_matrix), columns=list('xy'))
# Plot Data Visualization (Matplotlib)
df2d.plot(kind='scatter', x='x', y='y')
plt.title('Subtask1 and Subtask2a - Exploded Labelset')
plt.show()

# %%
# let's see what the smaller set looks like (non-exploded labels), but probably will be the same and shorter range

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(raw_documents=subtask1_2a['text']).toarray()

pca = PCA(n_components=2)

df2d = pd.DataFrame(pca.fit_transform(tfidf_matrix), columns=list('xy'))
# Plot Data Visualization (Matplotlib)
df2d.plot(kind='scatter', x='x', y='y')
plt.title('Subtask1 and Subtask2a')
plt.show()

# %%
# make documents for all class types from the big dataset

document_dict = {}

for i in labels:
    doc = big_subtasks[big_subtasks['labels'] == i]['text'].tolist()
    document_dict.update({f'{i}': doc})

document_list = []

for i in labels:
    document_list += document_dict[i]

# %%
vecs = vectorizer.fit_transform(document_list)
matrix = ((vecs * vecs.T).A)

for i in labels:
    dim = len(document_dict[i])
    similarity = matrix[dim:, :dim].mean()
    print(f'{i} similarity {similarity}')
# Out:
# Black-and-white Fallacy/Dictatorship similarity 0.02134642270802546
# Loaded Language similarity 0.02095949550102712
# Glittering generalities (Virtue) similarity 0.021427668204421088
# Thought-terminating cliché similarity 0.021448282409803884
# Whataboutism similarity 0.0214600680555694
# Slogans similarity 0.021311593316859504
# Causal Oversimplification similarity 0.021365774947463178
# Smears similarity 0.020853602432515612
# Name calling/Labeling similarity 0.02099252590022601
# Appeal to authority similarity 0.0213429837391016
# Exaggeration/Minimisation similarity 0.021562279631922903
# Repetition similarity 0.021575291089047828
# Flag-waving similarity 0.021306015039773914
# Appeal to fear/prejudice similarity 0.021611710714877705
# Reductio ad hitlerum similarity 0.02159105338228672
# Doubt similarity 0.021572439941034978
# Misrepresentation of Someone's Position (Straw Man) similarity 0.021621847785551613
# Obfuscation, Intentional vagueness, Confusion similarity 0.02222189901567721
# Bandwagon similarity 0.021481500325656204
# Presenting Irrelevant Data (Red Herring) similarity 0.02181059830246153
# Transfer similarity 0.021376114524014764
# Appeal to (Strong) Emotions similarity 0.021579277837235386

# %%
master_df = pd.DataFrame(columns=[x for x in labels], index=[x for x in labels])

for i in labels:
    for j in labels:
        corpus = [' '.join(document_dict[i]), ' '.join(document_dict[j])]
        trsfm = vectorizer.fit_transform(corpus)
        #print(cosine_similarity(trsfm))
        df = pd.DataFrame(cosine_similarity(trsfm, dense_output=True), columns=[i, j],index=[i, j])
        master_df.loc[i,j] = np.array(df)[0][1]

# %%
corr = master_df.corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
master_df = master_df.astype(float)
master_df.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_7e942_row0_col0, #T_7e942_row1_col1, #T_7e942_row2_col2, #T_7e942_row3_col3, #T_7e942_row4_col4, #T_7e942_row5_col5, #T_7e942_row6_col6, #T_7e942_row7_col7, #T_7e942_row8_col8, #T_7e942_row9_col9, #T_7e942_row10_col10, #T_7e942_row11_col11, #T_7e942_row12_col12, #T_7e942_row13_col13, #T_7e942_row14_col14, #T_7e942_row15_col15, #T_7e942_row16_col16, #T_7e942_row17_col17, #T_7e942_row18_col18, #T_7e942_row19_col19, #T_7e942_row20_col20, #T_7e942_row21_col21 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col1, #T_7e942_row1_col20, #T_7e942_row8_col9 {
#   background-color: #ac0026;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col2, #T_7e942_row8_col17, #T_7e942_row12_col20, #T_7e942_row14_col6 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col3, #T_7e942_row1_col0 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col4, #T_7e942_row10_col15, #T_7e942_row15_col21, #T_7e942_row21_col3 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col5, #T_7e942_row4_col6, #T_7e942_row4_col9, #T_7e942_row5_col13, #T_7e942_row7_col2, #T_7e942_row7_col5, #T_7e942_row9_col21, #T_7e942_row10_col6, #T_7e942_row20_col9 {
#   background-color: #d7121f;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col6, #T_7e942_row5_col9, #T_7e942_row10_col9, #T_7e942_row13_col11 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col7, #T_7e942_row7_col6, #T_7e942_row8_col20, #T_7e942_row9_col8, #T_7e942_row20_col3 {
#   background-color: #b40026;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col8, #T_7e942_row3_col8, #T_7e942_row7_col9, #T_7e942_row8_col15, #T_7e942_row15_col7 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col9, #T_7e942_row7_col10, #T_7e942_row9_col13, #T_7e942_row11_col6, #T_7e942_row11_col13, #T_7e942_row13_col15, #T_7e942_row15_col13, #T_7e942_row20_col21 {
#   background-color: #ca0923;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col10, #T_7e942_row1_col2, #T_7e942_row2_col11, #T_7e942_row5_col6, #T_7e942_row11_col4, #T_7e942_row14_col1 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col11, #T_7e942_row6_col8, #T_7e942_row9_col3, #T_7e942_row9_col11, #T_7e942_row13_col8, #T_7e942_row13_col20, #T_7e942_row20_col11, #T_7e942_row20_col15 {
#   background-color: #c30424;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col12, #T_7e942_row2_col14, #T_7e942_row10_col19, #T_7e942_row19_col1, #T_7e942_row19_col3, #T_7e942_row21_col19 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col13, #T_7e942_row1_col15, #T_7e942_row7_col4, #T_7e942_row8_col6, #T_7e942_row13_col3, #T_7e942_row20_col0, #T_7e942_row21_col1 {
#   background-color: #b90026;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col14, #T_7e942_row4_col3, #T_7e942_row5_col21, #T_7e942_row9_col2, #T_7e942_row21_col0, #T_7e942_row21_col4 {
#   background-color: #e31a1c;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col15, #T_7e942_row10_col11, #T_7e942_row11_col20, #T_7e942_row15_col6, #T_7e942_row15_col11, #T_7e942_row21_col8 {
#   background-color: #cb0a22;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col16, #T_7e942_row2_col0, #T_7e942_row9_col19, #T_7e942_row20_col16 {
#   background-color: #ee3122;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col17, #T_7e942_row11_col12 {
#   background-color: #fc532b;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col18, #T_7e942_row17_col1 {
#   background-color: #fd9a42;
#   color: #000000;
# }
# #T_7e942_row0_col19, #T_7e942_row2_col15, #T_7e942_row2_col20, #T_7e942_row9_col12, #T_7e942_row10_col5 {
#   background-color: #ed3022;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col20, #T_7e942_row3_col1, #T_7e942_row7_col0, #T_7e942_row7_col13, #T_7e942_row20_col8 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_7e942_row0_col21, #T_7e942_row11_col15 {
#   background-color: #ce0c22;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col3, #T_7e942_row1_col21, #T_7e942_row11_col8 {
#   background-color: #ae0026;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col4, #T_7e942_row8_col0, #T_7e942_row8_col13, #T_7e942_row10_col8, #T_7e942_row13_col7, #T_7e942_row20_col13 {
#   background-color: #be0126;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col5, #T_7e942_row2_col1, #T_7e942_row3_col10, #T_7e942_row3_col21, #T_7e942_row5_col7, #T_7e942_row9_col5, #T_7e942_row9_col15, #T_7e942_row10_col7, #T_7e942_row20_col10 {
#   background-color: #d41020;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col6, #T_7e942_row1_col11, #T_7e942_row13_col1, #T_7e942_row20_col1 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col7 {
#   background-color: #970026;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col8, #T_7e942_row7_col1, #T_7e942_row8_col1 {
#   background-color: #950026;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col9, #T_7e942_row6_col1, #T_7e942_row7_col3, #T_7e942_row7_col15, #T_7e942_row8_col3, #T_7e942_row11_col1 {
#   background-color: #b20026;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col10 {
#   background-color: #c50624;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col12 {
#   background-color: #f23924;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col13, #T_7e942_row20_col7 {
#   background-color: #a60026;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col14, #T_7e942_row2_col8, #T_7e942_row5_col1, #T_7e942_row5_col8, #T_7e942_row6_col11, #T_7e942_row12_col5, #T_7e942_row21_col7 {
#   background-color: #cd0b22;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col16, #T_7e942_row2_col13 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col17, #T_7e942_row5_col14, #T_7e942_row12_col3, #T_7e942_row12_col6 {
#   background-color: #f33b25;
#   color: #f1f1f1;
# }
# #T_7e942_row1_col18, #T_7e942_row14_col2, #T_7e942_row17_col7 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_7e942_row1_col19 {
#   background-color: #e0181d;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col3, #T_7e942_row8_col12, #T_7e942_row12_col13, #T_7e942_row14_col7, #T_7e942_row14_col9 {
#   background-color: #ed2e21;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col4, #T_7e942_row13_col5, #T_7e942_row21_col10 {
#   background-color: #e51e1d;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col5, #T_7e942_row8_col19, #T_7e942_row10_col13, #T_7e942_row11_col14, #T_7e942_row12_col8, #T_7e942_row13_col10, #T_7e942_row20_col5 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col6, #T_7e942_row10_col14, #T_7e942_row13_col19, #T_7e942_row15_col14 {
#   background-color: #eb2b21;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col7, #T_7e942_row5_col12, #T_7e942_row8_col14, #T_7e942_row10_col3, #T_7e942_row21_col13 {
#   background-color: #d00d21;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col9, #T_7e942_row4_col8, #T_7e942_row5_col11, #T_7e942_row6_col15, #T_7e942_row11_col0, #T_7e942_row11_col10 {
#   background-color: #cf0c21;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col10, #T_7e942_row10_col20, #T_7e942_row10_col21 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col12, #T_7e942_row4_col21, #T_7e942_row9_col4, #T_7e942_row12_col2, #T_7e942_row12_col9, #T_7e942_row15_col10, #T_7e942_row20_col14, #T_7e942_row21_col20 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col16 {
#   background-color: #fd933f;
#   color: #000000;
# }
# #T_7e942_row2_col17, #T_7e942_row2_col18, #T_7e942_row4_col17, #T_7e942_row12_col17, #T_7e942_row19_col0 {
#   background-color: #fd883b;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col19, #T_7e942_row16_col6, #T_7e942_row21_col17 {
#   background-color: #fc6c33;
#   color: #f1f1f1;
# }
# #T_7e942_row2_col21, #T_7e942_row3_col5, #T_7e942_row12_col1 {
#   background-color: #e6211e;
#   color: #f1f1f1;
# }
# #T_7e942_row3_col0, #T_7e942_row3_col7, #T_7e942_row3_col11, #T_7e942_row3_col13, #T_7e942_row3_col20, #T_7e942_row11_col3, #T_7e942_row15_col1 {
#   background-color: #bd0026;
#   color: #f1f1f1;
# }
# #T_7e942_row3_col2 {
#   background-color: #fc6430;
#   color: #f1f1f1;
# }
# #T_7e942_row3_col4, #T_7e942_row4_col0, #T_7e942_row4_col20, #T_7e942_row20_col19 {
#   background-color: #e61f1d;
#   color: #f1f1f1;
# }
# #T_7e942_row3_col6, #T_7e942_row7_col21, #T_7e942_row8_col21, #T_7e942_row15_col3 {
#   background-color: #c00225;
#   color: #f1f1f1;
# }
# #T_7e942_row3_col9, #T_7e942_row9_col6, #T_7e942_row9_col7, #T_7e942_row11_col9, #T_7e942_row13_col6 {
#   background-color: #c40524;
#   color: #f1f1f1;
# }
# #T_7e942_ro

# %% [markdown]
# # Vision

# %% [markdown]
# TO DO
