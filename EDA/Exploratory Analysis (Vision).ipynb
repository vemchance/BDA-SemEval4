# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %% [markdown]
# To do:
# - FaceNet would be good to look at whether an entity is male or female in different label types (+ race and other attributes)
# - Link to a KG - though unfortunately entity links are to the paid Google KG
# - NER the ents
#
# To update:
# - Finish faces analysis
# - Different analysis of fundamental features

# %% [markdown]
# # Data

# %%
anno_subtask2a_train = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2a\\train.json')
anno_subtask2a_train['subset'] = 'train'
anno_subtask2a_val = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2a\\validation.json')
anno_subtask2a_val['subset'] = 'val'
anno_subtask2a_dev = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2a\\dev_unlabeled.json')

anno_subtask2a_combined = pd.concat([anno_subtask2a_train, anno_subtask2a_val])

anno_subtask2b_train = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2b\\train.json')
anno_subtask2b_train['subset'] = 'train'
anno_subtask2b_val = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2b\\val.json')
anno_subtask2b_val['subset'] = 'val'
anno_subtask2b_dev = pd.read_json('X:\\PhD\\SemEval Task4\\Data\\annotations\\data\\subtask2b\\dev_unlabeled.json')

anno_subtask2b_combined = pd.concat([anno_subtask2b_train, anno_subtask2b_val])

# %%
path = r'X:\PhD\SemEval Task4\Data\subtask2a_images'
images = [os.path.join(dirpath,f) for (dirpath, dirnames, filenames) in os.walk(path) for f in filenames]
images_df = pd.DataFrame(images, columns=['filepath'])
images_df['image'] = images_df['filepath'].str.split('\\').str[-1]

subtask2a = pd.merge(anno_subtask2a_combined, images_df, on='image')

# %%
path = r'X:\PhD\SemEval Task4\Data\subtask2b_images'
images = [os.path.join(dirpath,f) for (dirpath, dirnames, filenames) in os.walk(path) for f in filenames]
images_df = pd.DataFrame(images, columns=['filepath'])
images_df['image'] = images_df['filepath'].str.split('\\').str[-1]

subtask2b = pd.merge(anno_subtask2b_combined, images_df, on='image')

# has a nan text field so replace it with an empty string
subtask2b['text'] = subtask2b['text'].fillna(' ')
subtask2b
# Out:
#          id                                               text  \
# 0     35807  DONALD TRUMP: BARACK\nOBAMA AND JOE BIDEN\nWIL...
# 1     30562  00\n10% FOR\nTHE BIG GUY\nNANCY'S\nCUT\n@ImMem...
# 2     44163  To much political posting online\nthese days, ...
# 3     24224  I DON'T THINK\nYOU UNDERSTOOD\nWHAT I SAID.\nY...
# 4     31611  ⒸSergey Mihailicenko/Anadolu Agency via Getty ...
# ...     ...                                                ...
# 1345  44900  197\nNazi ain't got no humanity\nThey're the f...
# 1346  12635                   HANG ONTHAVE\nA MEME\nFOR THIS\n
# 1347  12740  HE GAVE HIS BLOOD, SWEAT AND TEARS\nFOR THE AM...
# 1348  46086  BUT I WANTED NORTH\nKOREA TO NUKE US\nTO MAKE ...
# 1349  30279                         AGENDA 21\nDIY.DESPAIR.COM
#
#                     image               label subset  \
# 0      prop_meme_6570.png      propagandistic  train
# 1      prop_meme_8346.png      propagandistic  train
# 2     prop_meme_24378.png  non_propagandistic  train
# 3      prop_meme_2594.png      propagandistic  train
# 4      prop_meme_7654.png      propagandistic  train
# ...                   ...                 ...    ...
# 1345  prop_meme_19869.png      propagandistic    val
# 1346    prop_meme_641.png  non_propagandistic    val
# 1347    prop_meme_746.png      propagandistic    val
# 1348  prop_meme_18775.png      propagandistic    val
# 1349   prop_meme_5619.png      propagandistic    val
#
#                                                filepath
# 0     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 1     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 2     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 3     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# 4     X:\PhD\SemEval Task4\Data\subtask2b_images\tra...
# ...                                                 ...
# 1345  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1346  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1347  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1348  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
# 1349  X:\PhD\SemEval Task4\Data\subtask2b_images\val...
#
# [1350 rows x 6 columns]

# %% [markdown]
# # Entity Analysis

# %%
path_f = r'X:\PhD\SemEval Task4\Code\GoogleVision\vision_face_detect.json'
path_w = r'X:\PhD\SemEval Task4\Code\GoogleVision\web_entities.json'

with open(path_f) as f:
    faces = json.load(f)

with open(path_w) as f:
    web_ents = json.load(f)

# %% [markdown]
# The responses files from Google Vision are not great, so best way is to explode the interested columns in a dataframe instead of dealing with mismatched files. Setting the image ID as the index is also a good method for this. There is probably a better method....
#
# The entities are extracted for all images (Subtask2a and Subtask2b) so we also want to join the labels from those subtasks.

# %%
# function for sorting the JSON file a bit more sensibly to work with
# col is in the Response: e.g., webEntities, fullMatchingImages .etc, check the json

def explode_frame(json_file, col):
    df = pd.json_normalize(json_file)
    df.set_index('Image ID', inplace=True)
    return df['Response.' + col].explode().pipe(lambda x: pd.json_normalize(x).set_index(x.index))

# %% [markdown]
# ## Web Entities

# %%
web_ents = explode_frame(web_ents, 'webEntities')

# %%
# grab the labels, merge the frames
labels = pd.concat([subtask2a[['image', 'labels']], subtask2b[['image', 'label']]])
labels.rename(columns={'labels': '2a_label', 'label': '2b_label'}, inplace=True)
web_ents = web_ents.merge(labels, left_on=web_ents.index, right_on='image')

# %% [markdown]
# ### Subtask2b
# Start with the easiest....

# %%
# get a count of the top entities

web_ents2b = web_ents.dropna(subset='2b_label')
web_ents2b.groupby('description').count().sort_values(['entityId'], ascending=False).head(50)
# Out:
#                    entityId  score   id  image  2a_label  2b_label
# description
# Text                    813    813  813    813         0       813
# Photo caption           534    534  534    534         0       534
# Meter                   477    477  477    477         0       477
# Font                    380    380  380    380         0       380
# Image                   359    359  359    359         0       359
# Meme                    342    342  342    342         0       342
# Politics                251    251  251    251         0       251
# Internet meme           222    222  222    222         0       222
# funny                   218    218  218    218         0       218
# Funny meme              214    214  214    214         0       214
# Product                 209    209  209    209         0       209
# Human                   199    198  199    199         0       199
# Brand                   188    188  188    188         0       188
# United States           183    183  183    183         0       183
# US President            172    172  172    172         0       172
# M                       164    164  164    164         0       164
# Human behavior          161    161  161    161         0       161
# Photograph              140    140  140    140         0       140
# Behavior                133    133  133    133         0       133
# Forehead                132    132  132    132         0       132
# Poster                  109    109  109    109         0       109
# create                   99     99   99     99         0        99
# Public Relations         94     94   94     94         0        94
# Speech                   83     83   83     83         0        83
# Russia                   81     81   81     81         0        81
# Presentation             80     80   80     80         0        80
# Humor                    74     74   74     74         0        74
# Line                     69     69   69     69         0        69
# just                     67     67   67     67         0        67
# Public speaking          67     67   67     67         0        67
# iFunny                   66     66   66     66         0        66
# other                    63     63   63     63         0        63
# iFunny Brazil            62     62   62     62         0        62
# Imgflip                  62     62   62     62         0        62
# Public                   59     59   59     59         0        59
# Hair                     59     59   59     59         0        59
# Know Your Meme           56     56   56     56         0        56
# US Vice President        54     54   54     54         0        54
# Media                    51     51   51     51         0        51
# Ukraine                  51     51   51     51         0        51
# official                 51     51   51     51         0        51
# Facial hair              51     51   51     51         0        51
# Banner                   50     50   50     50         0        50
# Candidate                48     48   48     48         0        48
# past                     47     47   47     47         0        47
# 9GAG                     47     47   47     47         0        47
# Imgur                    45     45   45     45         0        45
# Entrepreneur             44     44   44     44         0        44
# Design                   43     43   43     43         0        43
# Album cover              42     42   42     42         0        42

# %%
# get a count of the top entities - by label?
web_ents2b[web_ents2b['2b_label'] == 'non_propagandistic'].groupby(['description', '2b_label']).count().sort_values(['entityId'], 
                                                                                                                    ascending=False).head(50)
# Out:
#                                    entityId  score   id  image  2a_label
# description    2b_label
# Text           non_propagandistic       164    164  164    164         0
# Meme           non_propagandistic       122    122  122    122         0
# Image          non_propagandistic       121    121  121    121         0
# funny          non_propagandistic       102    102  102    102         0
# Funny meme     non_propagandistic       100    100  100    100         0
# Meter          non_propagandistic        92     92   92     92         0
# Font           non_propagandistic        91     91   91     91         0
# Internet meme  non_propagandistic        88     88   88     88         0
# Product        non_propagandistic        66     66   66     66         0
# Brand          non_propagandistic        62     62   62     62         0
# Photo caption  non_propagandistic        49     49   49     49         0
# Line           non_propagandistic        46     46   46     46         0
# M              non_propagandistic        44     44   44     44         0
# Humor          non_propagandistic        30     30   30     30         0
# Photograph     non_propagandistic        30     30   30     30         0
# Human          non_propagandistic        26     26   26     26         0
# Number         non_propagandistic        26     26   26     26         0
# Politics       non_propagandistic        24     24   24     24         0
# 9GAG           non_propagandistic        24     24   24     24         0
# Cartoon        non_propagandistic        23     23   23     23         0
# Know Your Meme non_propagandistic        23     23   23     23         0
# iFunny         non_propagandistic        21     21   21     21         0
# Logo           non_propagandistic        21     21   21     21         0
# create         non_propagandistic        21     21   21     21         0
# Banner         non_propagandistic        21     21   21     21         0
# iFunny Brazil  non_propagandistic        20     20   20     20         0
# just           non_propagandistic        20     20   20     20         0
# other          non_propagandistic        19     19   19     19         0
# Poster         non_propagandistic        18     18   18     18         0
# Human behavior non_propagandistic        17     17   17     17         0
# Imgflip        non_propagandistic        17     17   17     17         0
# Design         non_propagandistic        15     15   15     15         0
# Imgur          non_propagandistic        15     15   15     15         0
# Organism       non_propagandistic        15     15   15     15         0
# Forehead       non_propagandistic        15     15   15     15         0
# Cat            non_propagandistic        15     15   15     15         0
# Graphics       non_propagandistic        14     14   14     14         0
# Handwriting    non_propagandistic        14     14   14     14         0
# Culture        non_propagandistic        14     14   14     14         0
# Hair           non_propagandistic        14     14   14     14         0
# United States  non_propagandistic        13     13   13     13         0
# Face           non_propagandistic        13     13   13     13         0
# used           non_propagandistic        12     12   12     12         0
# Snout          non_propagandistic        12     12   12     12         0
# US President   non_propagandistic        12     12   12     12         0
# Reddit         non_propagandistic        12     12   12     12         0
# Business       non_propagandistic        11     11   11     11         0
# Behavior       non_propagandistic        11     11   11     11         0
# Mammal         non_propagandistic        10     10   10     10         0
# Document       non_propagandistic        10     10   10     10         0

# %%
web_ents2b[web_ents2b['2b_label'] == 'propagandistic'].groupby(['description', '2b_label']).count().sort_values(['entityId'], 
                                                                                                                    ascending=False).head(50)
# Out:
#                                             entityId  score   id  image  \
# description                 2b_label
# Text                        propagandistic       649    649  649    649
# Photo caption               propagandistic       485    485  485    485
# Meter                       propagandistic       385    385  385    385
# Font                        propagandistic       289    289  289    289
# Image                       propagandistic       238    238  238    238
# Politics                    propagandistic       227    227  227    227
# Meme                        propagandistic       220    220  220    220
# Human                       propagandistic       173    172  173    173
# United States               propagandistic       170    170  170    170
# US President                propagandistic       160    160  160    160
# Human behavior              propagandistic       144    144  144    144
# Product                     propagandistic       143    143  143    143
# Internet meme               propagandistic       134    134  134    134
# Brand                       propagandistic       126    126  126    126
# Behavior                    propagandistic       122    122  122    122
# M                           propagandistic       120    120  120    120
# Forehead                    propagandistic       117    117  117    117
# funny                       propagandistic       116    116  116    116
# Funny meme                  propagandistic       114    114  114    114
# Photograph                  propagandistic       110    110  110    110
# Poster                      propagandistic        91     91   91     91
# Public Relations            propagandistic        85     85   85     85
# Russia                      propagandistic        79     79   79     79
# create                      propagandistic        78     78   78     78
# Speech                      propagandistic        75     75   75     75
# Presentation                propagandistic        73     73   73     73
# Public speaking             propagandistic        62     62   62     62
# Public                      propagandistic        53     53   53     53
# US Vice President           propagandistic        49     49   49     49
# Ukraine                     propagandistic        49     49   49     49
# Media                       propagandistic        48     48   48     48
# just                        propagandistic        47     47   47     47
# official                    propagandistic        46     46   46     46
# Hair                        propagandistic        45     45   45     45
# Imgflip                     propagandistic        45     45   45     45
# iFunny                      propagandistic        45     45   45     45
# other                       propagandistic        44     44   44     44
# Humor                       propagandistic        44     44   44     44
# Candidate                   propagandistic        44     44   44     44
# iFunny Brazil               propagandistic        42     42   42     42
# Facial hair                 propagandistic        42     42   42     42
# Entrepreneur                propagandistic        39     39   39     39
# past                        propagandistic        38     38   38     38
# Album cover                 propagandistic        36     36   36     36
# Black-and-white             propagandistic        36     36   36     36
# Russian invasion of Ukraine propagandistic        34     34   34     34
# Gentleman                   propagandistic        34     34   34     34
# Know Your Meme              propagandistic        33     33   33     33
# Album                       propagandistic        32     32   32     32
# Motivational speaker        propagandistic        31     31   31     31
#
#                                             2a_label
# description                 2b_label
# Text                        propagandistic         0
# Photo caption               propagandistic         0
# Meter                       propagandistic         0
# Font                        propagandistic         0
# Image                       propagandistic         0
# Politics                    propagandistic         0
# Meme                        propagandistic         0
# Human                       propagandistic         0
# United States               propagandistic         0
# US President                propagandistic         0
# Human behavior              propagandistic         0
# Product                     propagandistic         0
# Internet meme               propagandistic         0
# Brand                       propagandistic         0
# Behavior                    propagandistic         0
# M                           propagandistic         0
# Forehead                    propagandistic         0
# funny                       propagandistic         0
# Funny meme                  propagandistic         0
# Photograph                  propagandistic         0
# Poster                      propagandistic         0
# Public Relations            propagandistic         0
# Russia                      propagandistic         0
# create                      propagandistic         0
# Speech                      propagandistic         0
# Presentation                propagandistic         0
# Public speaking             propagandistic         0
# Public                      propagandistic         0
# US Vice President           propagandistic         0
# Ukraine                     propagandistic         0
# Media                       propagandistic         0
# just                        propagandistic         0
# official                    propagandistic         0
# Hair                        propagandistic         0
# Imgflip                     propagandistic         0
# iFunny                      propagandistic         0
# other                       propagandistic         0
# Humor                       propagandistic         0
# Candidate                   propagandistic         0
# iFunny Brazil               propagandistic         0
# Facial hair                 propagandistic         0
# Entrepreneur                propagandistic         0
# past                        propagandistic         0
# Album cover                 propagandistic         0
# Black-and-white             propagandistic         0
# Russian invasion of Ukraine propagandistic         0
# Gentleman                   propagandistic         0
# Know Your Meme              propagandistic         0
# Album                       propagandistic         0
# Motivational speaker        propagandistic         0

# %% [markdown]
# ### Subtask2a
# Since we probably went to look at the different top entities appearing per label, we'll do the largest counts per label in a loop.

# %%
web_ents2a = web_ents.dropna(subset='2a_label')
web_ents2a = web_ents2a.explode(['2a_label']) # row per label

# %%
labels = web_ents2a['2a_label'].unique()

for i in labels:
    print(f'Top entities for "{i}"')
    print(web_ents2a[web_ents2a['2a_label'] == i].groupby(['description']).count().sort_values(['entityId'], ascending=False).head(20))
    print(f'\n---------')
# Out:
# Top entities for "Black-and-white Fallacy/Dictatorship"
#                 entityId  score   id  image  2a_label  2b_label
# description
# Text                 444    444  444    444       444         0
# Photo caption        305    305  305    305       305         0
# Meter                269    269  269    269       269         0
# Font                 233    233  233    233       233         0
# Meme                 150    150  150    150       150         0
# Image                129    129  129    129       129         0
# Human                128    127  128    128       128         0
# Brand                118    118  118    118       118         0
# Human behavior       115    115  115    115       115         0
# Politics             113    113  113    113       113         0
# Product              104    104  104    104       104         0
# United States         95     95   95     95        95         0
# US President          91     91   91     91        91         0
# Behavior              90     90   90     90        90         0
# M                     86     86   86     86        86         0
# Internet meme         85     85   85     85        85         0
# funny                 82     82   82     82        82         0
# Photograph            78     78   78     78        78         0
# Funny meme            73     73   73     73        73         0
# create                69     69   69     69        69         0
#
# ---------
# Top entities for "Thought-terminating cliché"
#                 entityId  score   id  image  2a_label  2b_label
# description
# Text                 351    351  351    351       351         0
# Photo caption        250    250  250    250       250         0
# Meter                224    224  224    224       224         0
# Font                 166    166  166    166       166         0
# Human                106    105  106    106       106         0
# Human behavior        94     94   94     94        94         0
# Behavior              84     84   84     84        84         0
# Product               82     82   82     82        82         0
# Meme                  81     81   81     81        81         0
# Brand                 77     77   77     77        77         0
# Image                 70     70   70     70        70         0
# Internet meme         63     63   63     63        63         0
# M                     63     63   63     63        63         0
# Politics              59     59   59     59        59         0
# Poster                51     51   51     51        51         0
# United States         50     50   50     50        50         0
# funny                 46     46   46     46        46         0
# US President          42     42   42     42        42         0
# Russia                39     39   39     39        39         0
# Forehead              38     38   38     38        38         0
#
# ---------
# Top entities for "Appeal to authority"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   657    657  657    657       657         0
# Photo caption          506    506  506    506       506         0
# Meter                  355    355  355    355       355         0
# Human                  295    294  295    295       295         0
# Font                   292    292  292    292       292         0
# Human behavior         283    283  283    283       283         0
# Behavior               228    228  228    228       228         0
# Politics               179    179  179    179       179         0
# United States          148    148  148    148       148         0
# US President           137    137  137    137       137         0
# Brand                  134    134  134    134       134         0
# Public Relations       121    121  121    121       121         0
# Quotation              104    104  104    104       104         0
# Forehead                98     98   98     98        98         0
# Poster                  98     98   98     98        98         0
# M                       92     92   92     92        92         0
# Speech                  87     87   87     87        87         0
# Presentation            81     81   81     81        81         0
# Public speaking         75     75   75     75        75         0
# Photograph              70     70   70     70        70         0
#
# ---------
# Top entities for "Repetition"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   182    182  182    182       182         0
# Photo caption          131    131  131    131       131         0
# Meter                  111    111  111    111       111         0
# Font                    92     92   92     92        92         0
# Meme                    68     68   68     68        68         0
# Human                   61     61   61     61        61         0
# Image                   57     57   57     57        57         0
# Human behavior          55     55   55     55        55         0
# Behavior                49     49   49     49        49         0
# Politics                47     47   47     47        47         0
# United States           46     46   46     46        46         0
# Internet meme           45     45   45     45        45         0
# Product                 43     43   43     43        43         0
# US President            41     41   41     41        41         0
# Brand                   35     35   35     35        35         0
# Funny meme              35     35   35     35        35         0
# funny                   34     34   34     34        34         0
# Poster                  34     34   34     34        34         0
# M                       29     29   29     29        29         0
# Public Relations        26     26   26     26        26         0
#
# ---------
# Top entities for "Name calling/Labeling"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   963    963  963    963       963         0
# Photo caption          753    753  753    753       753         0
# Meter                  590    590  590    590       590         0
# Font                   408    408  408    408       408         0
# Human                  345    343  345    345       345         0
# Human behavior         315    315  315    315       315         0
# Meme                   305    305  305    305       305         0
# Politics               300    300  300    300       300         0
# Behavior               266    266  266    266       266         0
# Image                  263    263  263    263       263         0
# Product                197    197  197    197       197         0
# Brand                  180    180  180    180       180         0
# United States          180    180  180    180       180         0
# US President           179    179  179    179       179         0
# Internet meme          177    177  177    177       177         0
# funny                  166    166  166    166       166         0
# Funny meme             156    156  156    156       156         0
# Poster                 154    154  154    154       154         0
# Public Relations       150    150  150    150       150         0
# Photograph             145    145  145    145       145         0
#
# ---------
# Top entities for "Slogans"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   422    422  422    422       422         0
# Meter                  267    267  267    267       267         0
# Photo caption          258    258  258    258       258         0
# Font                   240    240  240    240       240         0
# Poster                 115    115  115    115       115         0
# Brand                  115    115  115    115       115         0
# Product                113    113  113    113       113         0
# Human                  111    111  111    111       111         0
# Image                  102    102  102    102       102         0
# Politics                99     99   99     99        99         0
# Meme                    94     94   94     94        94         0
# Human behavior          92     92   92     92        92         0
# United States           88     88   88     88        88         0
# M                       84     84   84     84        84         0
# Behavior                76     76   76     76        76         0
# US President            65     65   65     65        65         0
# Internet meme           64     64   64     64        64         0
# create                  53     53   53     53        53         0
# Public Relations        53     53   53     53        53         0
# Banner                  42     42   42     42        42         0
#
# ---------
# Top entities for "Transfer"
#                 entityId  score   id  image  2a_label  2b_label
# description
# Text                 689    689  689    689       689         0
# Meme                 478    478  478    478       478         0
# Photo caption        462    462  462    462       462         0
# Meter                437    437  437    437       437         0
# Image                408    408  408    408       408         0
# Font                 328    328  328    328       328         0
# Internet meme        317    317  317    317       317         0
# Funny meme           250    250  250    250       250         0
# Politics             245    245  245    245       245         0
# funny                234    234  234    234       234         0
# Product              175    175  175    175       175         0
# Human                172    168  172    172       172         0
# Poster               164    164  164    164       164         0
# Russia               158    158  158    158       158         0
# Brand                149    149  149    149       149         0
# United States        141    141  141    141       141         0
# Photograph           137    137  137    137       137         0
# Ukraine              135    135  135    135       135         0
# create               123    123  123    123       123         0
# Human behavior       122    122  122    122       122         0
#
# ---------
# Top entities for "Glittering generalities (Virtue)"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   408    408  408    408       408         0
# Photo caption          332    332  332    332       332         0
# Meter                  240    240  240    240       240         0
# US President           185    185  185    185       185         0
# Politics               171    171  171    171       171         0
# Font                   163    163  163    163       163         0
# Human                  122    122  122    122       122         0
# United States          113    113  113    113       113         0
# Human behavior         108    108  108    108       108         0
# Public Relations       101    101  101    101       101         0
# Brand                   96     96   96     96        96         0
# Meme                    90     90   90     90        90         0
# Image                   87     87   87     87        87         0
# Behavior                85     85   85     85        85         0
# Product                 76     76   76     76        76         0
# Poster                  72     72   72     72        72         0
# Speech                  68     68   68     68        68         0
# Photograph              67     67   67     67        67         0
# Public speaking         66     66   66     66        66         0
# Internet meme           60     60   60     60        60         0
#
# ---------
# Top entities for "Presenting Irrelevant Data (Red Herring)"
#                 entityId  score  id  image  2a_label  2b_label
# description
# Text                  39     39  39     39        39         0
# Meme                  28     28  28     28        28         0
# Photo caption         22     22  22     22        22         0
# Meter                 19     19  19     19        19         0
# Internet meme         18     18  18     18        18         0
# Image                 16     16  16     16        16         0
# Font                  14     14  14     14        14         0
# Human                 10     10  10     10        10         0
# Funny meme             9      9   9      9         9         0
# funny                  8      8   8      8         8         0
# Entrepreneur           8      8   8      8         8         0
# Human behavior         8      8   8      8         8         0
# just                   8      8   8      8         8         0
# Business               7      7   7      7         7         0
# Ukraine                7      7   7      7         7         0
# Product                7      7   7      7         7         0
# Politics               7      7   7      7         7         0
# Russia                 7      7   7      7         7         0
# equal                  6      6   6      6         6         0
# Clothing               6      6   6      6         6         0
#
# ---------
# Top entities for "Whataboutism"
#                 entityId  score   id  image  2a_label  2b_label
# description
# Text                 183    183  183    183       183         0
# Photo caption        141    141  141    141       141         0
# Meter                101    101  101    101       101         0
# Font                  80     80   80     80        80         0
# Image                 74     74   74     74        74         0
# Meme                  68     68   68     68        68         0
# Human                 62     62   62     62        62         0
# Human behavior        59     59   59     59        59         0
# Politics              55     55   55     55        55         0
# Behavior              42     42   42     42        42         0
# Photograph            42     42   42     42        42         0
# funny                 40     40   40     40        40         0
# Forehead              39     39   39     39        39         0
# Internet meme         38     38   38     38        38         0
# Funny meme            36     36   36     36        36         0
# create                32     32   32     32        32         0
# Product               31     31   31     31        31         0
# Presentation          30     30   30     30        30         0
# US President          29     29   29     29        29         0
# Brand                 29     29   29     29        29         0
#
# ---------
# Top entities for "Loaded Language"
#                   entityId  score    id  image  2a_label  2b_label
# description
# Text                  1160   1160  1160   1160      1160         0
# Photo caption          849    849   849    849       849         0
# Meter                  719    719   719    719       719         0
# Font                   548    548   548    548       548         0
# Human                  390    384   390    390       390         0
# Human behavior         342    342   342    342       342         0
# Image                  332    332   332    332       332         0
# Meme                   326    326   326    326       326         0
# Behavior               284    284   284    284       284         0
# Brand                  246    246   246    246       246         0
# Politics               231    231   231    231       231         0
# Product                225    225   225    225       225         0
# Internet meme          190    190   190    190       190         0
# M                      190    190   190    190       190         0
# United States          189    189   189    189       189         0
# Photograph             182    182   182    182       182         0
# Forehead               170    170   170    170       170         0
# Funny meme             165    165   165    165       165         0
# funny                  163    163   163    163       163         0
# Public Relations       153    153   153    153       153         0
#
# ---------
# Top entities for "Appeal to fear/prejudice"
#                 entityId  score   id  image  2a_label  2b_label
# description
# Text                 271    271  271    271       271         0
# Meter                173    173  173    173       173         0
# Photo caption        169    169  169    169       169         0
# Font                 139    139  139    139       139         0
# Image                 87     87   87     87        87         0
# Meme                  81     81   81     81        81         0
# Human                 72     71   72     72        72         0
# Brand                 68     68   68     68        68         0
# Human behavior        65     65   65     65        65         0
# Product               64     64   64     64        64         0
# Poster                60     60   60     60        60         0
# Politics              57     57   57     57        57         0
# M                     55     55   55     55        55         0
# Behavior              54     54   54     54        54         0
# Internet meme         50     50   50     50        50         0
# Funny meme            48     48   48     48        48         0
# Photograph            48     48   48     48        48         0
# United States         43     43   43     43        43         0
# funny                 43     43   43     43        43         0
# US President          39     39   39     39        39         0
#
# ---------
# Top entities for "Smears"
#                   entityId  score    id  image  2a_label  2b_label
# description
# Text                  1938   1938  1938   1938      1938         0
# Photo caption         1507   1507  1507   1507      1507         0
# Meter                 1180   1180  1180   1180      1180         0
# Meme                   958    958   958    958       958         0
# Font                   797    797   797    797       797         0
# Image                  781    781   781    781       781         0
# Politics               761    761   761    761       761         0
# Internet meme          584    584   584    584       584         0
# Human                  578    571   578    578       578         0
# Human behavior         488    488   488    488       488         0
# funny                  484    484   484    484       484         0
# Funny meme             479    479   479    479       479         0
# Product                428    428   428    428       428         0
# Behavior               422    422   422    422       422         0
# US President           406    406   406    406       406         0
# Brand                  402    402   402    402       402         0
# United States          395    395   395    395       395         0
# Photograph             347    347   347    347       347         0
# Public Relations       325    325   325    325       325         0
# Forehead               324    324   324    324       324         0
#
# ---------
# Top entities for "Appeal to (Strong) Emotions"
#                        entityId  score   id  image  2a_label  2b_label
# description
# Text                        135    135  135    135       135         0
# Photo caption               104    104  104    104       104         0
# Meter                        99     99   99     99        99         0
# Font                         70     70   70     70        70         0
# Photograph                   56     56   56     56        56         0
# Image                        56     56   56     56        56         0
# Human                        51     50   51     51        51         0
# Poster                       48     48   48     48        48         0
# Russia                       48     48   48     48        48         0
# Product                      43     43   43     43        43         0
# Human behavior               42     42   42     42        42         0
# Meme                         38     38   38     38        38         0
# United States                35     35   35     35        35         0
# Amnesty International        34     34   34     34        34         0
# M                            33     33   33     33        33         0
# Politics                     32     32   32     32        32         0
# Ukraine                      31     31   31     31        31         0
# create                       31     31   31     31        31         0
# Behavior                     30     30   30     30        30         0
# Brand                        27     27   27     27        27         0
#
# ---------
# Top entities for "Doubt"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   259    259  259    259       259         0
# Photo caption          187    187  187    187       187         0
# Meter                  174    174  174    174       174         0
# Font                   131    131  131    131       131         0
# Meme                    83     83   83     83        83         0
# Human                   79     79   79     79        79         0
# Human behavior          78     78   78     78        78         0
# Image                   72     72   72     72        72         0
# Behavior                61     61   61     61        61         0
# M                       57     57   57     57        57         0
# Product                 55     55   55     55        55         0
# Brand                   52     52   52     52        52         0
# Politics                48     48   48     48        48         0
# Internet meme           45     45   45     45        45         0
# Public Relations        40     40   40     40        40         0
# Speech                  39     39   39     39        39         0
# Forehead                36     36   36     36        36         0
# Photograph              34     34   34     34        34         0
# funny                   31     31   31     31        31         0
# Public speaking         31     31   31     31        31         0
#
# ---------
# Top entities for "Flag-waving"
#                            entityId  score   id  image  2a_label  2b_label
# description
# Text                            483    483  483    483       483         0
# Photo caption                   342    342  342    342       342         0
# Meter                           315    315  315    315       315         0
# United States                   212    212  212    212       212         0
# Font                            200    200  200    200       200         0
# Politics                        173    173  173    173       173         0
# US President                    155    155  155    155       155         0
# Image                           118    118  118    118       118         0
# Brand                           115    115  115    115       115         0
# Human                            95     93   95     95        95         0
# Product                          86     86   86     86        86         0
# Poster                           85     85   85     85        85         0
# Speech                           84     84   84     84        84         0
# Flag                             84     84   84     84        84         0
# Meme                             83     83   83     83        83         0
# M                                83     83   83     83        83         0
# Human behavior                   81     81   81     81        81         0
# Public Relations                 78     78   78     78        78         0
# Flag of the United States        71     71   71     71        71         0
# Behavior                         69     69   69     69        69         0
#
# ---------
# Top entities for "Causal Oversimplification"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   200    200  200    200       200         0
# Meter                  127    127  127    127       127         0
# Photo caption          126    126  126    126       126         0
# Font                    97     97   97     97        97         0
# Meme                    61     61   61     61        61         0
# Human behavior          57     57   57     57        57         0
# Human                   56     56   56     56        56         0
# Image                   51     51   51     51        51         0
# Behavior                45     45   45     45        45         0
# Product                 43     43   43     43        43         0
# Brand                   41     41   41     41        41         0
# Internet meme           36     36   36     36        36         0
# Poster                  33     33   33     33        33         0
# Funny meme              33     33   33     33        33         0
# funny                   30     30   30     30        30         0
# Forehead                29     29   29     29        29         0
# Public Relations        28     28   28     28        28         0
# Photograph              26     26   26     26        26         0
# M                       26     26   26     26        26         0
# United States           23     23   23     23        23         0
#
# ---------
# Top entities for "Obfuscation, Intentional vagueness, Confusion"
#                 entityId  score  id  image  2a_label  2b_label
# description
# Text                  34     34  34     34        34         0
# Meter                 16     16  16     16        16         0
# Photo caption         15     15  15     15        15         0
# Font                  11     11  11     11        11         0
# Product                8      8   8      8         8         0
# Photograph             8      8   8      8         8         0
# Image                  8      8   8      8         8         0
# Politics               7      7   7      7         7         0
# Brand                  7      7   7      7         7         0
# Meme                   7      7   7      7         7         0
# Human                  7      7   7      7         7         0
# Human behavior         7      7   7      7         7         0
# Behavior               7      7   7      7         7         0
# Album cover            6      6   6      6         6         0
# Christmas              6      6   6      6         6         0
# Getty Images           6      6   6      6         6         0
# 2023                   6      6   6      6         6         0
# United States          6      6   6      6         6         0
# Motor vehicle          5      5   5      5         5         0
# Christmas Tree         5      5   5      5         5         0
#
# ---------
# Top entities for "Reductio ad hitlerum"
#                 entityId  score  id  image  2a_label  2b_label
# description
# Text                  67     67  67     67        67         0
# Photo caption         45     45  45     45        45         0
# Meter                 43     43  43     43        43         0
# Font                  38     38  38     38        38         0
# United States         27     27  27     27        27         0
# Human behavior        23     23  23     23        23         0
# Human                 23     23  23     23        23         0
# Image                 23     23  23     23        23         0
# Meme                  22     22  22     22        22         0
# Politics              21     21  21     21        21         0
# Behavior              20     20  20     20        20         0
# Poster                18     18  18     18        18         0
# Forehead              17     17  17     17        17         0
# Product               16     16  16     16        16         0
# Brand                 14     14  14     14        14         0
# Photograph            14     14  14     14        14         0
# Russia                13     13  13     13        13         0
# Internet meme         12     12  12     12        12         0
# Al-Qaeda              12     12  12     12        12         0
# past                  11     11  11     11        11         0
#
# ---------
# Top entities for "Exaggeration/Minimisation"
#                   entityId  score   id  image  2a_label  2b_label
# description
# Text                   243    243  243    243       243         0
# Photo caption          207    207  207    207       207         0
# Meter                  144    144  144    144       144         0
# Font                   103    103  103    103       103         0
# Human                   90     90   90     90        90         0
# Politics                90     90   90     90        90         0
# Human behavior          88     88   88     88        88         0
# US President            73     73   73     73        73         0
# Behavior                72     72   72     72        72         0
# Meme                    64     64   64     64        64         0
# United States           61     61   61     61        61         0
# Image                   60     60   60     60        60         0
# Brand                   54     54   54     54        54         0
# Public Relations        50     50   50     50        50         0
# Product                 46     46   46     46        46         0
# Forehead                42     42   42     42        42         0
# funny                   42     42   42     42        42         0
# Internet meme           37     37   37     37        37         0
# Hair                    36     36   36     36        36         0
# Public speaking         34     34   34     34        34         0
#
# ---------
# Top entities for "Misrepresentation of Someone's Position (Straw Man)"
#                 entityId  score  id  image  2a_label  2b_label
# description
# Text                  40     40  40     40        40         0
# Photo caption         39     39  39     39        39         0
# Image                 31     31  31     31        31         0
# Meme                  27     27  27     27        27         0
# Politics              23     23  23     23        23         0
# Meter                 22     22  22     22        22         0
# funny                 20     20  20     20        20         0
# Font                  19     19  19     19        19         0
# Funny meme            18     18  18     18        18         0
# Internet meme         15     15  15     15        15         0
# Human behavior        15     15  15     15        15         0
# Human                 14     14  14     14        14         0
# United States         12     12  12     12        12         0
# Photograph            12     12  12     12        12         0
# Behavior              11     11  11     11        11         0
# Forehead              10     10  10     10        10         0
# US President           9      9   9      9         9         0
# Russia                 8      8   8      8         8         0
# Humor                  8      8   8      8         8         0
# Product                7      7   7      7         7         0
#
# ---------
# Top entities for "Bandwagon"
#                     entityId  score  id  image  2a_label  2b_label
# description
# Text                      63     63  63     63        63         0
# Photo caption             56     56  56     56        56         0
# Meter                     42     42  42     42        42         0
# Font                      24     24  24     24        24         0
# US President              23     23  23     23        23         0
# United States             22     22  22     22        22         0
# Politics                  20     20  20     20        20         0
# Image                     19     19  19     19        19         0
# Product                   18     18  18     18        18         0
# Brand                     14     14  14     14        14         0
# US Vice President         14     14  14     14        14         0
# World Trade Center        13     13  13     13        13         0
# Human                     11     11  11     11        11         0
# Human behavior            11     11  11     11        11         0
# Photograph                11     11  11     11        11         0
# Speech                    11     11  11     11        11         0
# Behavior                  10     10  10     10        10         0
# Laughter                  10     10  10     10        10         0
# Photography                9      9   9      9         9         0
# Public Relations           9      9   9      9         9         0
#
# ---------
# Top entities for "nan"
# Empty DataFrame
# Columns: [entityId, score, id, image, 2a_label, 2b_label]
# Index: []
#
# ---------

# %% [markdown]
# ## Faces

# %% [markdown]
# Info from API response:
#
# CLASS LIKELIHOOD
# Values: UNKNOWN (0): Unknown likelihood. VERY_UNLIKELY (1): It is very unlikely. UNLIKELY (2): It is unlikely. POSSIBLE (3): It is possible. LIKELY (4): It is likely. VERY_LIKELY (5): It is very likely.
#
# See more: https://cloud.google.com/python/docs/reference/vision/latest/google.cloud.vision_v1.types.FaceAnnotation
#
# Probably for now, most interested in the headwear annotations and emotions.r.

# %%
# different response, function doesn't work but don't need it here anyway

df = pd.json_normalize(faces)
df.set_index('Image ID', inplace=True)
df = df['Response'].explode().pipe(lambda x: pd.json_normalize(x).set_index(x.index))

headwear = df[['headwear_likelihood']]
emotions = df[['joy_likelihood', 'sorrow_likelihood', 'anger_likelihood', 'surprise_likelihood']]

# %%
labels = pd.concat([subtask2a[['image', 'labels']], subtask2b[['image', 'label']]])
labels.rename(columns={'labels': '2a_label', 'label': '2b_label'}, inplace=True)
headwear = headwear.merge(labels, left_on=headwear.index, right_on='image')
emotions = emotions.merge(labels, left_on=emotions.index, right_on='image')

# %%
emotions[emotions['anger_likelihood'] > 2.0]
# Out:
#        joy_likelihood  sorrow_likelihood  anger_likelihood  \
# 512               1.0                1.0               4.0
# 513               1.0                1.0               4.0
# 514               1.0                1.0               4.0
# 515               1.0                1.0               4.0
# 986               1.0                1.0               4.0
# ...               ...                ...               ...
# 18995             1.0                2.0               3.0
# 19138             1.0                1.0               3.0
# 19140             1.0                1.0               3.0
# 19774             1.0                1.0               4.0
# 19876             1.0                1.0               3.0
#
#        surprise_likelihood                image  \
# 512                    1.0  prop_meme_12478.png
# 513                    1.0  prop_meme_12478.png
# 514                    1.0  prop_meme_12478.png
# 515                    1.0  prop_meme_12478.png
# 986                    3.0  prop_meme_16753.png
# ...                    ...                  ...
# 18995                  1.0   prop_meme_9814.png
# 19138                  4.0  prop_meme_12951.png
# 19140                  1.0  prop_meme_12967.png
# 19774                  1.0   prop_meme_3648.png
# 19876                  1.0   prop_meme_9699.png
#
#                                                 2a_label            2b_label
# 512               [Black-and-white Fallacy/Dictatorship]                 NaN
# 513               [Black-and-white Fallacy/Dictatorship]                 NaN
# 514               [Black-and-white Fallacy/Dictatorship]                 NaN
# 515               [Black-and-white Fallacy/Dictatorship]                 NaN
# 986                  [Loaded Language, Transfer, Smears]                 NaN
# ...                                                  ...                 ...
# 18995  [Presenting Irrelevant Data (Red Herring), Sme...                 NaN
# 19138                                                NaN      propagandistic
# 19140                                                NaN      propagandistic
# 19774                                                NaN      propagandistic
# 19876                                                NaN  non_propagandistic
#
# [132 rows x 7 columns]

# %%
# stopped here, will update later
